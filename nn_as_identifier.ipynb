# %%
using LinearAlgebra
using ControlSystems
using Plots
using ControlSystemIdentification
using Random
using Statistics
using CUDA
using Flux
using DelimitedFiles

include("KugaPack.jl")
include("sysid.jl")
include("blockpack.jl")
include("analysis.jl")

CUDA.allowscalar(true)

# %%
#numerical conditions are set up
dt =5e-3;
maxT = 5;
ns = round(Int,maxT/dt)+1;
t = 0:dt:maxT;

ny = 2
ns
# Out:
# 1001

# %%
#problem conditions are set up
x0 = [0; 0; 0; 0;];

U = [1; zeros(ns-1)];

# %%
data_size = 5000
m_max = 10
ξ_max = 0.4
k_max = 1000

Respostas = Vector{Vector}(undef,data_size)

Param = GenParam(m_max,ξ_max,k_max,data_size)

for i=1:data_size
    sysP,sysD = F2DOF(dt,Param[i]);
    Y,_,_= lsim(sysD,U',t,x0=x0); #time response   
    Respostas[i] = vec(reshape(Y,(ny*ns,1)));
end

#sub-amortecidos apenas -> em torno de um comportamento mais conhecido
#troca a função de ativação

# %%
png(
    plot(
    t, 
    reshape(Respostas[rand(1:data_size)],(ny,ns))',
    labels=["Massa 1" "Massa 2"],
    ylabel = "Posição (m)", 
    xlabel = "Tempo",
    title  = "Deslocamento das massas - Sistema Simulado",
),"amostra_ncontrolado");

# %%
#using the given parameters, the system (discrete space state) is created 
ParamOr = [0.77 0.59 2.1 1.2 9 200 200 200];
sysP,sysD = F2DOF(dt,ParamOr);

Y,_,_= lsim(sysD,U',t,x0=x0); #time response
magD,phaseD,w = bode(sysD); #frequency response

# %%
png(
    plot(
    t, 
    Y',
    labels=["Massa 1" "Massa 2"],
    ylabel = "Posição (m)", 
    xlabel = "Tempo",
    title  = "Deslocamento das massas - Sistema Objetivo",
),"amostra_ncontrolado");

# %%
Data = zip(Respostas |> gpu ,Param |> gpu)
V = [ns*ny, 1000, 8]
model = Simple(V,σ)

model = TrainModel(model,Data)

ParamEst = model(reshape(Y,(ns*ny,1)) |> gpu)
sysPest,sysDest = F2DOF(dt,[Float64(i) for i in ParamEst]);
Yest,_,_= lsim(sysDest,U',t,x0=x0); 

plot(t,[Y' Yest'])

# %%
Entradas = ns*ny;
Saidas = 8;
maxIt = 30
passo = 1

iter = (1:maxIt).*passo


InfoGen = Matrix{Float64}(undef, maxIt,maxIt)

ModelAval = reshape(Y,(ns*ny,1)) |> gpu

for i in iter
    for j in iter
        print(string(i)*"-"*string(j)*"\r")
        V = Int.([Entradas; i*ones(j); Saidas])
        model = TrainModel(Simple(V,relu),Data)
        ParamEst = model(ModelAval)
        sysPest,sysDest = F2DOF(dt,[Float64(i) for i in ParamEst]);
        Yest,_,_= lsim(sysDest,U',t,x0=x0); 
        l = Int64(round(i/passo))
        m = Int64(round(j/passo))
        InfoGen[l,m] = norm(Y- Yest)/norm(Y)
    end
end

minimum(InfoGen) #1.267426861614698
writedlm( "infogen.csv",  InfoGen, ';')

# %%
png(
    plot(
    heatmap(InfoGen), 
    ylabel = "Largura da Rede", 
    xlabel = "Profundidade da Rede",
    title  = "Erro na Identificação - Rede Identificadora",
),"rede_identificadora_erro");

# %%
InfoGen = readdlm("dados/infogen.csv", ';', Float64)
InfoGen2 = readdlm("dados/infogen_restrito2.csv", ';', Float64)

# %%
zoom = 10:30

png(
    plot(
    heatmap(zoom,zoom,InfoGen[zoom,zoom]), 
    ylabel = "Largura da Rede", 
    xlabel = "Profundidade da Rede",
    title  = "Erro na Identificação - Rede Identificadora",
),"erro_infogen_ampliado");

# %%
zoom = 13:30

png(
    plot(
    heatmap(zoom,zoom,InfoGen2[zoom,zoom]), 
    ylabel = "Largura da Rede", 
    xlabel = "Profundidade da Rede",
    title  = "Erro na Identificação - Rede Identificadora",
),"erro_infogen2_sub_ampliado");

# %%
Data = zip(Respostas |> gpu ,Param |> gpu)
V = Int.([ns*ny; 11*ones(22); 8])

model = TrainModel(Simple(V,relu),Data)

ParamEst = model(reshape(Y,(ns*ny,1)) |> gpu)
sysPest,sysDest = F2DOF(dt,[Float64(i) for i in ParamEst]);
Yest,_,_= lsim(sysDest,U',t,x0=x0); 

png(
    plot(
    t,
    [Y' Yest'], 
    ylabel = "Largura da Rede", 
    xlabel = "Profundidade da Rede",
    labels=["Massa 1" "Massa 2" "Massa 1 - estimado" "Massa 2 - estimado"],
    title  = "Erro na Identificação - Rede Identificadora",
),"resposta_rede_identificacao1");
